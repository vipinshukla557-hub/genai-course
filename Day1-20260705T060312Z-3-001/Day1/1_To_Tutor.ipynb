# %% [markdown]
# # function

# %% [markdown]
# print("hello")

# %%
print("hello")
# Out:
# hello

# %%
def say_hello():
    print("hello genAI engineers")

say_hello()
# Out:
# hello genAI engineers

# %%
def greet(name):
    print(f"hello,{name}")

greet("Jeff")
# Out:
# hello,Jeff

# %%
def add(a,b):
    result = a+b
    return result

total = add(655,6)
print(total)
# Out:
# 661

# %%
def format_message(role,text):
    message = {"role":role, "content":text}
    return message

msg = format_message("user","what is ai")
print(msg)
# Out:
# {'role': 'user', 'content': 'what is ai'}
