# %%
print("Hello World")
print("Python is working!")
# Out:
# Hello World
# Python is working!

# %%
a = 10
b = 12

sum = a+b

print(sum)
# Out:
# 22

# %%
# variable

# %% [markdown]
# # variable

# %% [markdown]
# a = "saurav"

# %%
a = "saurav"

# %%
a = 10

# %%
a, b = 10, 11

print(a , b)
# Out:
# 10 11

# %% [markdown]
# # Data Types

# %% [markdown]
# Integer -
#
# string - ""
#
# float - 1.222
#
# Boolean - 1/0, Yes/No

# %%
a = "text"

a = 'this is also text'

# %%
pi = 3.14768787585

# %% [markdown]
# # List

# %% [markdown]
# a = [1,2,3,4,5,6]

# %% [markdown]
# List, dictionary, Tuple and Set

# %%
a = [1,2,3,4,5,6]

# %%
a[4]
# Out:
# 5

# %%
a[1:3]
# Out:
# [2, 3]

# %%
a[2:5]
# Out:
# [3, 4, 5]

# %%
a[:3]
# Out:
# [1, 2, 3]

# %%
a[2:]
# Out:
# [3, 4, 5, 6]

# %%
Prompt = ["What is AI","What is ML", 567, 34.5]

# %%
print(Prompt)
# Out:
# ['What is AI', 'What is ML', 567, 34.5]

# %%
Prompt = [12, [3,4,5], "Saurav"]

# %%
Prompt[1][0]
# Out:
# 3

# %%
a = [3,5,6,7,85,4,34]

# %%
a.append(56)

# %%
a
# Out:
# [3, 5, 6, 7, 85, 4, 34, 56]

# %%
a.remove(5)

# %%
a
# Out:
# [3, 6, 7, 85, 4, 34, 56]

# %%
a_set = {2,3,4,4,4,4,4}

# %%
a_set
# Out:
# {2, 3, 4}

# %% [markdown]
# # Dictionary

# %% [markdown]
# movies = {""}

# %%
movies = {"title":"3_idiots", "Year":2006, "rating":5.6}

# %%
movies["Year"]
# Out:
# 2006

# %%
std = {"name":"Aarav","city":"Pune"}

# %%
std["course"] = "GenAi"

# %%
std
# Out:
# {'name': 'Aarav', 'city': 'Pune', 'course': 'GenAi'}

# %%
std["age"] = 23
std
# Out:
# {'name': 'Aarav', 'city': 'Pune', 'course': 'GenAi', 'age': 23}

# %%
std["pin"] = "411017"
std
# Out:
# {'name': 'Aarav',
#  'city': 'Pune',
#  'course': 'GenAi',
#  'age': 23,
#  'pin': '411017'}

# %%
del std["pin"]
std
# Out:
# {'name': 'Aarav', 'city': 'Pune', 'course': 'GenAi', 'age': 23}

# %%
message = {    "role":"user",    "content":"Explain AI"}

print(message)

messages = [{"role":"system","content":"You are a helpful assistant"},message]

print(messages)
# Out:
# {'role': 'user', 'content': 'Explain AI'}
# [{'role': 'system', 'content': 'You are a helpful assistant'}, {'role': 'user', 'content': 'Explain AI'}]

# %%
message = {
    "role":"user",
    "content":"Explain AI"
}

print(message)

messages = [
    {
        "role":"system",
        "content":"You are a helpful assistant"
    },
    {
        "role":"user",
        "content":"Explain AI"
    }
]

print(messages)

# %% [markdown]
# # if else

# %% [markdown]
# age = 22
#
# if

# %%
topic = "Avadhoot"

if topic == "GenAI":
    print("Using GenAI expert")
elif topic == "finance":
    print("finance")
else:
    print("General")
# Out:
# General

# %% [markdown]
# # loop

# %% [markdown]
# numbers = [2,4,9]
#
# for

# %%
numbers = [2,4,9,6,4,5,6]

for i in numbers:
    print(i)
# Out:
# 2
# 4
# 9
# 6
# 4
# 5
# 6

# %%
Prompt = ["What is AI","What is ML", 567, 34.5]

for i in Prompt:
    print(i)
# Out:
# What is AI
# What is ML
# 567
# 34.5

# %%
messages = [
    {"role":"user","content":"Hello"},
    {"role":"assistant","content":"Hi"}
]

for i in messages:
    print(i)
# Out:
# {'role': 'user', 'content': 'Hello'}
# {'role': 'assistant', 'content': 'Hi'}

# %%
costs = {"got-4o":0.005,"got-4o-mini":0.000015,"claude-sonnet":0.4}

for model, cost in costs.items():
    print(f"{model} -> {cost}")
# Out:
# got-4o -> 0.005
# got-4o-mini -> 1.5e-05
# claude-sonnet -> 0.4

# %%
name = "Vipin"

print("hello "+ name)
# Out:
# hello Vipin

# %%
name = "Devika"

print(f"hello {name}")
# Out:
# hello Devika

# %% [markdown]
# # Import

# %%
import math

print(math.sqrt(25))
# Out:
# 5.0

# %%
import json

print("Json we will be using for our API calls")

# %%
try:
    number = int(input("Enter a number: "))
    print(number)
except:
    print("Please enter a valid number")
# Out:
# Please enter a valid number
